# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRaiicHu/pandas/blob/main/inmuebles_cdmx.ipynb?forceRefresh=true">
#   <img src="https://drive.google.com/uc?export=view&id=191Woxwut0iaIL2hCcCIeXRSB6oba_88H" alt="Abrir en Colab" width="120"/>
# </a>
#
# # **Pandas**

# %% [markdown]
# ### Datos de importación

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ## **Importando la Base de Datos**

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"
pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
#read_csv lectura del archivo csv, sep delimitador de ;
pd.read_csv(url,sep=";")
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
# almacenamos en la variable datos
# datos es el DataFrame completo
datos = pd.read_csv(url,sep=";")
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
# muestra las primeras 5 filas del dataset
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# muestra las 5 ultimas filas del dataset
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
# muestra las primeras 10 filas del dataset
datos.head(10) # se define la cantidad en los paréntesis
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
# una muestra de 10 filas aleatorias del dataset
datos.sample(10) # se define la cantidad en los paréntesis
# Out:
#                           Tipo                 Colonia  Habitaciones  Garages  \
# 18049             Departamento                    Roma             2        1
# 3925   Conjunto Comercial/Sala        Centro Histórico             0        0
# 18853             Departamento                Narvarte             2        0
# 22898             Departamento               Nativitas             1        0
# 3133              Departamento  San Miguel Chapultepec             2        1
# 23596             Departamento                Coyoacán             3        1
# 9722              Departamento              Peralvillo             2        1
# 8740                      Loft                 Condesa             1        0
# 3422   Conjunto Comercial/Sala                Santa Fe             0        1
# 21623  Conjunto Comercial/Sala        Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 18049       0    64  12250.0      3209.5     532.0
# ...

# %%
# tipo de dato # permite visualizar, manipular los datos y hacer una serie de operaciones de nuestros datos.
print(type(datos))
# type(datos) - > me arroja información de la función
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## **Exploración inicial de los datos**

# %%
datos.sample(5)
# Out:
#                Tipo             Colonia  Habitaciones  Garages  Suites  Area  \
# 11039  Departamento            Coyoacán             4        3       1   340
# 17460  Departamento           San Ángel             2        1       0    70
# 24260  Departamento            Coyoacán             2        1       0    70
# 12714  Tienda/Salón            Coyoacán             0        0       0    33
# 655    Departamento  Villa de Guadalupe             2        1       1    58
#
#          Valor  Condominio  Impuesto
# 11039  80500.0     14000.0   70000.0
# 17460  11900.0      2418.5     315.0
# 24260  38150.0     12250.0    5250.0
# 12714  15750.0      4900.0    1470.0
# 655     4725.0      2065.0    1960.0

# %%
# primer elemento de la tupla: cantidad de filas, segundo elemento de la tupla: cantidad de columnas.
datos.shape
# Out:
# (25121, 9)

# %%
datos.index
# Out:
# RangeIndex(start=0, stop=25121, step=1)

# %%
# Devuelve un objeto Index con los nombres de todas las columnas del DataFrame.
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
# se usa para resumir información general de un DataFrame
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
# Es una Serie que representa una sola columna.
datos['Tipo'] #objects -> strings (cadena de caracteres)
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
# Es un DataFrame que contiene solo las columnas "Habitaciones" y "Valor".
datos[['Habitaciones','Valor']] #int64 -> enteros, float64 -> decimales
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# ## **Demandas de Machine Learning**

# %% [markdown]
# ### **Análisis exploratorio de loa datos**

# %% [markdown]
# #### ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# calcula el promedio de TODOS los valores presentes en la columna 'Valor' del DataFrame datos
datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %% [markdown]
# Pero lo que quiero son los valores promedio de alquiler por tipo de propiedad.

# %%
# Agrupa el DataFrame 'datos' por la columna 'Tipo' y calcula el promedio de las columnas numéricas dentro de cada grupo.
# NO SE USA, YA QUE TRAE TODOS LOS DATOS Y NO TODOS SON NUMÉRICOS, Y EN ESTE EJERCICIO SOLO QUEREMOS EL PROMEDIO DE LOS VALORES.
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
# Agrupa el DataFrame 'datos' por la columna 'Tipo', selecciona la columna 'Valor' y calcula el promedio de los valores de alquiler para cada tipo de inmueble.
# Agrupa los datos por "Tipo"
# Luego toma la columna "Valor"
# Y calcula el promedio (mean()) por cada grupo.
# ESTE SI ANDA BIEN Y MUESTRA LO QUE NECESITO

datos.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
# [['Valor']]: Usa doble corchete para seleccionar la columna 'Valor', devolviendo un DataFrame en lugar de una Serie.
# .sort_values('Valor'): Ordena el DataFrame resultante por los valores de la columna 'Valor' en orden ascendente.
datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
# Almacena un DataFrame (con el valor promedio por tipo, ordenado) en la variable 'df_tipo_precio'.
# .sort_values('Valor') ordena el DataFrame de manera ascendente
# .sort_values('Valor', ascending=False) para ordenar de manera descendente
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', # Gráfico de barras horizontales
                    figsize=(12,8), # Tamaño de 12x8
                    color='purple') # Color púrpura
# Out:
# <Axes: ylabel='Tipo'>

# %%
# Obtiene los nombres distintos (valores únicos) de la columna 'Tipo' del DataFrame 'datos'.
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
# Lista de tipos de inmuebles comerciales identificados a partir de la inspección de los valores únicos en la columna 'Tipo'.
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial', 'Terreno Estándar', 'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial','Hotel', 'Loteo/Condominio','Industria']

# %%
# Devuelve un nuevo DataFrame que contiene solo las filas de datos donde la columna "Tipo" coincide con alguno de los valores presentes en la lista inmuebles_comerciales
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
# selecciona las filas donde el tipo de inmueble no está en la lista de inmuebles comerciales
# Lo que te daría como resultado un DataFrame con los inmuebles residenciales.
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
# Almacenamos el DataFrame que representará a los Inmuebles Residenciales
df_inmuebles_residenciales = datos.query('@inmuebles_comerciales not in Tipo')
df_inmuebles_residenciales
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
# Inmuebles residenciales entre el rango de valor
df_inmuebles_residenciales.query('Valor >= 5000 and  Valor <= 8000')
# Out:
#                Tipo   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 0          Cocineta   Condesa             1        0       0    40  5950.0
# 8      Departamento   Condesa             1        0       1    40  7000.0
# 9          Cocineta   Condesa             1        0       0    27  6300.0
# 13     Departamento  Santa Fe             2        1       1    67  5950.0
# 14     Departamento  Narvarte             2        1       0   110  6650.0
# ...             ...       ...           ...      ...     ...   ...     ...
# 25090  Departamento  Coyoacán             1        0       0    55  7000.0
# 25092  Departamento  Santa Fe             1        1       0    62  5950.0
# 25103  Departamento   Condesa             1        0       0    50  6825.0
# 25105  Departamento  Santa Fe             2        1       1    85  7875.0
# 25109      Cocineta   Condesa             1        0       0    22  5250.0
#
#        Condominio  Impuesto
# 0          1750.0     210.0
# ...

# %%
# Cocinetas entre el rango de valor
df_inmuebles_residenciales.query('Tipo == "Cocineta" and 5000 <= Valor <= 8000')
# Out:
#            Tipo               Colonia  Habitaciones  Garages  Suites  Area  \
# 0      Cocineta               Condesa             1        0       0    40
# 9      Cocineta               Condesa             1        0       0    27
# 256    Cocineta  Lomas de Chapultepec             1        0       0    30
# 329    Cocineta  Lomas de Chapultepec             1        0       0    25
# 345    Cocineta               Condesa             1        0       0    35
# ...         ...                   ...           ...      ...     ...   ...
# 23821  Cocineta              Santa Fe             1        1       1    20
# 24318  Cocineta  Lomas de Chapultepec             1        0       0    21
# 24701  Cocineta               Condesa             1        0       0    36
# 24974  Cocineta               Condesa             1        0       0    32
# 25109  Cocineta               Condesa             1        0       0    22
#
#         Valor  Condominio  Impuesto
# ...

# %%
# calcula el valor promedio de alquiler para cada tipo de inmueble residencial
# y luego genera un gráfico de barras horizontales para visualizar esos promedios
df_tipo_precio = df_inmuebles_residenciales.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', # Gráfico de barras horizontales
                    figsize=(12,8), # Tamaño de 12x8
                    color='purple') # Color púrpura
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# #### Porcentaje de cada tipo de inmuebles presentes en la Base de Datos

# %%
# Se utiliza la función unique() para identificar los diferentes tipos de propiedades presentes en el DataFrame.
df_inmuebles_residenciales.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
# Se emplea el método value_counts() para contar la frecuencia con la que aparece cada tipo de propiedad
df_inmuebles_residenciales.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
# EJEMPLO
# Creamos un DataFrame con los porcentajes de cada tipo de inmueble
# y renombramos la columna resultante como "Porcentajes"
df_inmuebles_residenciales['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# Guardando el DataFrame en una variable
df_ejemplo = df_inmuebles_residenciales['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# Cambiando el nombre de la columna "Tipo" a "Porcentajes"
df_ejemplo.rename(columns={'proportion': 'Porcentajes'}, inplace=True)


# Visualizando el DataFrame
df_ejemplo
# Out:
#                        Porcentajes
# Tipo
# Casa                      0.031487
# Casa de Condominio        0.035242
# Casa de Vecindad          0.009128
# Cocineta                  0.041943
# Departamento              0.852967
# Departamento en Hotel     0.026287
# Estudio                   0.000231
# Loft                      0.002195
# Posada/Chalé              0.000058
# Rancho                    0.000462

# %%
# Cálculo del porcentaje de cada tipo de propiedad
# Se utiliza el parámetro normalize=True en el método value_counts() para obtener el porcentaje de cada tipo de propiedad en lugar del conteo absoluto
df_inmuebles_residenciales.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_tipo = df_inmuebles_residenciales.Tipo.value_counts(normalize=True).to_frame()
# Se crea un gráfico de barras utilizando el método plot() para visualizar los porcentajes de cada tipo de propiedad
porcentaje_tipo.plot(kind='bar',
                     figsize=(12,8),
                     color='green',
                     xlabel='Tipos',
                     ylabel='Porcentajes')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentajes'>

# %%
porcentaje = df_inmuebles_residenciales['Tipo'].value_counts(normalize=True)

umbral = 0.02
tipos_filtrados = porcentaje[porcentaje >= umbral]
otros = porcentaje[porcentaje < umbral]

porcentaje_ajustado = tipos_filtrados.copy()
porcentaje_ajustado['Otros'] = otros.sum()

# Gráfico 1: tipos principales
porcentaje_ajustado.plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8),
    ylabel=''
)
# Out:
# <Axes: >

# %%
# Gráfico 2: tipos que fueron agrupados en "Otros"
otros.plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8),
    ylabel=''
)
# Out:
# <Axes: >

# %%
df_inmuebles_residenciales.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# Se utiliza el método query() para seleccionar únicamente las filas del DataFrame que corresponden a un tipo de propiedad específico
# (en este caso, "departamento").
# Esto permite crear un nuevo DataFrame que contenga solo los datos relevantes para el análisis posterior.
df_departamentos = df_inmuebles_residenciales.query('Tipo == "Departamento"')
df_departamentos.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
# Número de Filas vs Número de Columnas
df_departamentos.shape
# Out:
# (14764, 9)

# %% [markdown]
# ### EJERCICIO DE ML

# %% [markdown]
# #### El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:
#
# 1. Calcular el promedio de habitaciones por departamento.
#
# 2. Verificar cuántas colonias únicas existen en nuestra base de datos.
#
# 3. Analizar qué colonias tienen el promedio de alquiler más alto.
#
# 4. Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

# %%
# 1. Calcular el promedio de habitaciones por departamento.
print("Promedio de",df_departamentos['Habitaciones'].mean(),"habitaciones.")
# Out:
# Promedio de 2.5041994039555675 habitaciones.

# %%
# 2. Verificar cuántas colonias únicas existen en nuestra base de datos.
colonias = datos.Colonia.unique()
colonias
# Out:
# array(['Condesa', 'Polanco', 'Santa Fe', 'Centro Histórico', 'Del Valle',
#        'Roma', 'Narvarte', 'Lomas de Chapultepec', 'Coyoacán',
#        'San Pedro de los Pinos', 'San Ángel', 'San Jerónimo',
#        'Ciudad de los Deportes', 'Villa Coapa', 'Bosques de las Lomas',
#        'Juárez', 'Chapultepec', 'Lindavista', 'La Condesa',
#        'San Miguel Chapultepec', 'Mixcoac', 'El Rosedal',
#        'Nueva Santa María', 'Arboledas', 'Villa de Cortés', 'Casa Blanca',
#        'Bosques de Aragón', 'La Florida', 'Álvaro Obregón', 'Iztacalco',
#        'Peralvillo', 'Napoles', 'Nativitas', 'San Rafael', 'Vallejo',
#        'Tlalpan', 'Pueblo Culhuacán', 'San Antonio Tecomitl',
#        'Roma Norte', 'Industrial Vallejo', 'Iztapalapa',
#        'Santa Marta Acatitla', 'Villa de Guadalupe', 'Tláhuac',
#        'Lomas de Padierna', 'El Contadero', 'San Mateo', 'Las Águilas',
#        'Culhuacán CTM', 'Santa María la Ribera', 'El Arenal',
# ...

# %%
print('La Base de Datos contiene',len(colonias),'colonias')
# Out:
# La Base de Datos contiene 88 colonias

# %%
# 3. Analizar qué colonias tienen el promedio de alquiler más alto.
#sort_values() -> para ordenar #mean() -> promedios
promedios_colonias = df_inmuebles_residenciales.groupby('Colonia')['Valor'].mean().sort_values(ascending=False)
promedios_colonias
# Out:
# Colonia
# Los Alpes                    58707.173913
# Xochimilco                   36925.000000
# Bosques de Aragón            32621.289474
# Coyoacán                     32186.409021
# Lomas de Chapultepec         30081.735272
#                                  ...
# Santa Marta Acatitla          2302.391304
# Las Aguilas                   2100.000000
# Santa María Aztahuacán        2030.000000
# San Mateo                     1750.000000
# Potrero de San Bernardino     1190.000000
# Name: Valor, Length: 87, dtype: float64

# %%
# Las 5 colonias con el promedio de alquiler más alto
top_colonias = promedios_colonias.head(5)
top_colonias
# Out:
# Colonia
# Los Alpes               58707.173913
# Xochimilco              36925.000000
# Bosques de Aragón       32621.289474
# Coyoacán                32186.409021
# Lomas de Chapultepec    30081.735272
# Name: Valor, dtype: float64

# %%
# Gráfico del promedio de los alquileres más altos en Inmuebles Residenciales
top_colonias.name = 'Promedio del alquiler'
top_colonias.plot(kind='bar',
                         figsize=(12,8),
                         title='Promedio de alquileres más altos en Inmuebles Residenciales',
                         color="#108eb7",
                         xlabel='Colonias',
                         ylabel='Alquileres',
                         legend=True
                         )
# Out:
# <Axes: title={'center': 'Promedio de alquileres más altos en Inmuebles Residenciales'}, xlabel='Colonias', ylabel='Alquileres'>

# %% [markdown]
# ### **Tratamiento de Datos Nulos**

# %%
# Transforma el DataFrame en un DataFrame con valores booleanos
# True si es que es nulo, False si no es nulo
df_departamentos.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
# Suma uno a uno los elementos que sean nulos y entrega el total
df_departamentos.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
# Los valores nulos les asignaremos valor 0
df_departamentos.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# Reemplazamos los valores nulos en el DataFrame con el valor 0
df_departamentos =  df_departamentos.fillna(0)
# Comprobamos que no hayan valores nulos
df_departamentos.isnull().sum()


# df_departamentos['Colonia'] = df_departamentos['Colonia'].fillna('') -> en caso de que algun campo de Colonia tuviera valores nulos
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ### **Remover registros inconsistentes**

# %%
# Le pregunto a mi DataFrame el Valor es igual a 0 ó Condominio es igual a 0
df_departamentos.query('Valor==0 | Condominio==0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
# Muestro solo los índices con presencia de valores igual a 0
df_departamentos.query('Valor==0 | Condominio==0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
# Creamos una variable que almacena los índices de filas a remover
indices_departamentos_remover = df_departamentos.query('Valor==0 | Condominio==0').index

# %%
# drop() REMOVEMOS todos los departamentos de nuestro DataFrame con Valores y Condominio igual a 0
#_____________________________________________________________________________________________
# axis=0 indica que se deben eliminar filas. En Pandas, el eje 0 representa las filas (el índice).
# axis=1 indicaría que se deben eliminar columnas. En Pandas, el eje 1 representa las columnas.
# El parámetro inplace determina si la operación de eliminación se realiza directamente sobre el DataFrame original o si se crea una copia del DataFrame con las filas eliminadas.
# inplace=True significa que la operación se realiza directamente sobre el DataFrame original, modificándolo permanentemente.

df_departamentos.drop(indices_departamentos_remover,axis=0,inplace=True)

# %%
# Se comprueba que las filas cuyos datos tenían valores 0, fueron eliminadas
df_departamentos.query('Valor==0 | Condominio==0').index
# Out:
# Index([], dtype='int64')

# %%
# Revisamos nuestros datos como están quedando
df_departamentos.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
# Verificamos que solo tenemos departamentos como datos únicos
df_departamentos.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
# En este caso, aliminaremos la columna 'Tipo', ya que no la recesitaremos
df_departamentos.drop('Tipo',axis=1,inplace=True)
# Mostramos el DataFrame con filas aleatorias
df_departamentos.sample(10)
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 10725                Santa Fe             4        2       1   145  16800.0
# 23517                Narvarte             2        1       1    95   5775.0
# 9335                  Polanco             4        3       1   165  28000.0
# 13511                Santa Fe             4        3       3   550  84000.0
# 9514                  Condesa             1        0       1    40   4900.0
# 22606                 Tlalpan             3        1       0   110  19250.0
# 20964                Santa Fe             2        1       2    63   8400.0
# 16146                Santa Fe             4        1       1   205  14700.0
# 15326    Bosques de las Lomas             1        0       0   110  15750.0
# 4693   San Miguel Chapultepec             2        1       1   101   6650.0
#
#        Condominio  Impuesto
# 10725      9534.0    1785.0
# 23517      3500.0       0.0
# 9335       7000.0    1792.0
# ...

# %% [markdown]
# ### **Creando Filtros**

# %% [markdown]
# #### 1. Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
# Primer filtro
# Crea una serie de booleanos, en donde cada elemento indica si el número de habitaciones en la columna es igual a uno
# Devuelve True o False
# Esta línea de código devuelve una máscara (o filtro)
filtro_1 = df_departamentos['Habitaciones'] == 1

# %%
# Mostramos la selección
filtro_1
# Out:
# 3         True
# 4         True
# 8         True
# 10       False
# 13       False
#          ...
# 25111    False
# 25113    False
# 25114     True
# 25118    False
# 25119    False
# Name: Habitaciones, Length: 14264, dtype: bool

# %%
# devuelve el tipo
type(filtro_1)
# pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
# DataFrame filtrado
df_departamentos[filtro_1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
# Segundo filtro
filtro_2 = df_departamentos['Valor'] < 4200
df_departamentos[filtro_2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# ...

# %%
# Para verificar que nuestro filtro esté funcionando, podemos usar la funcion max
df_departamentos[filtro_2].max()
# Vemos que el valor de alquiler máximo es menor a 4200
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
# Creamos una MÁSCARA que COMBINA dos (pueden ser más) condiciones para FILTRAR un DataFrame.
departamentos_filtrados_1 = (filtro_1) & (filtro_2)
departamentos_filtrados_1
# Out:
# 3         True
# 4         True
# 8        False
# 10       False
# 13       False
#          ...
# 25111    False
# 25113    False
# 25114     True
# 25118    False
# 25119    False
# Length: 14264, dtype: bool

# %%
df_departamentos[departamentos_filtrados_1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
# Aplicamos el filtro a una nueva variable
df_departamentos_1 = df_departamentos[departamentos_filtrados_1]
# Mostramos
df_departamentos_1.sample(10)
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 4651                  Condesa             1        0       0    31  3850.0
# 17866               Moctezuma             1        0       0    40  2135.0
# 3453               Iztapalapa             1        0       0    50  2800.0
# 12684               Nativitas             1        0       0    36  3850.0
# 4089                  Condesa             1        0       0    28  3325.0
# 13979            El Contadero             1        1       0    30  3500.0
# 13149  San Miguel Chapultepec             1        0       0    35  3850.0
# 21353   Jardines de San Mateo             1        1       1    50  2800.0
# 7034         Centro Histórico             1        0       0    34  2800.0
# 1602        Nueva Santa María             1        1       1    51  2975.0
#
#        Condominio  Impuesto
# 4651       1771.0     203.0
# 17866       332.5       0.0
# 3453        980.0       0.0
# ...

# %% [markdown]
# #### 2. Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
# Podemos simplificar todo de manera más rápida aplicando todos los filtros de una sola vez.
departamentos_filtrados_2 = (df_departamentos['Habitaciones'] >= 2) & (df_departamentos['Valor'] < 10500) & (df_departamentos['Area'] > 70)
df_departamentos[departamentos_filtrados_2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
# Aplicamos el filtro en una nueva variable
df_departamentos_2 = df_departamentos[departamentos_filtrados_2]
# Mostramos
df_departamentos_2.head(10)
# Out:
#      Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14  Narvarte             2        1       0   110  6650.0      2450.0
# 16  Narvarte             2        1       0    78  7000.0      2450.0
# 21      Roma             2        1       0    76  8750.0      2590.0
# 33  Santa Fe             3        1       1    72  8225.0      2100.0
# 58  Santa Fe             3        2       1   104  9100.0      4774.0
# 60  Santa Fe             2        1       1    88  9450.0      4550.0
# 63  Santa Fe             3        2       2    85  8750.0      4900.0
# 68  Santa Fe             2        1       1    78  9625.0      4550.0
# 75  Narvarte             2        1       0    80  6300.0      3850.0
# 79  Narvarte             3        1       0   172  9450.0      2730.0
#
#     Impuesto
# 14     483.0
# 16       0.0
# 21       0.0
# 33     245.0
# 58    1421.0
# 60    7147.0
# 63     665.0
# 68     483.0
# 75     294.0
# 79     595.0

# %% [markdown]
# ### **Guardando los archivos**

# %% [markdown]
# #### **df_departamentos**

# %%
# Guarda el archivo del primer DataFrame (df_departamentos)
df_departamentos.to_csv('inmuebles_ml.csv')

# %%
pd.read_csv('inmuebles_ml.csv')
# Pero me muestra el índice, y no lo queremos
# Out:
#        Unnamed: 0               Colonia  Habitaciones  Garages  Suites  Area  \
# 0               3      Centro Histórico             1        0       0    15
# 1               4             Del Valle             1        0       0    48
# 2               8               Condesa             1        0       1    40
# 3              10               Condesa             4        3       1   243
# 4              13              Santa Fe             2        1       1    67
# ...           ...                   ...           ...      ...     ...   ...
# 14259       25111  Lomas de Chapultepec             3        0       1    80
# 14260       25113              Coyoacán             3        1       2   150
# 14261       25114              Narvarte             1        0       0    28
# 14262       25118               Mixcoac             2        1       0    48
# 14263       25119  Lomas de Chapultepec             2        0       0    70
#
#          Valor  Condominio  Impuesto
# ...

# %%
# Ahora lo sobreescribimos pero sin índice
df_departamentos.to_csv('inmuebles_ml.csv',index=False)
# Leemos el archivo resultante
pd.read_csv('inmuebles_ml.csv')
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %%
# Ahora lo sobreescribimos con formato de separación igual al original, con ';'
df_departamentos.to_csv('inmuebles_ml.csv',index=False,sep=';')
# Leemos el archivo resultante
pd.read_csv('inmuebles_ml.csv',sep=';')
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %% [markdown]
# #### **df_departamentos_1**

# %%
df_departamentos_1.to_csv('inmuebles_ml_filtro1.csv',index=False,sep=';')

# %% [markdown]
# #### **df_departamentos_2**

# %%
df_departamentos_2.to_csv('inmuebles_ml_filtro2.csv',index=False,sep=';')

# %% [markdown]
# #### **Mover los datos a Google Drive**

# %%
# Permitimos el acceso de Google Drive
# Luego copiamos la ruta de nuestra carpeta en Google Drive
#/content/drive/MyDrive/Pandas/
# Ahora podemos guardar los DataFrame en GoogleDrive
df_departamentos.to_csv('/content/drive/MyDrive/Pandas/inmuebles_ml.csv',index=False,sep=';')
df_departamentos_1.to_csv('/content/drive/MyDrive/Pandas/inmuebles_ml_filtro1.csv',index=False,sep=';')
df_departamentos_2.to_csv('/content/drive/MyDrive/Pandas/inmuebles_ml_filtro2.csv',index=False,sep=';')

# %% [markdown]
# ## **Demandas de DEV**

# %% [markdown]
# ### **Crear columnas numéricas**

# %% [markdown]
# #### 1. valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.

# %%
#read_csv lectura del archivo csv, sep delimitador de ;
pd.read_csv(url,sep=";")
# Comprobamos que están todos los datos del DataFrame original
datos.shape
# Out:
# (25121, 9)

# %%
# Crear nueva columna de valor mensual, con la suma de alquiler (Valor) + Condominio
datos['Valor_mensual'] = datos['Valor'] + datos['Condominio']
# Mostramos el resultado del DF
datos.head(5)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# #### 2. valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
# Crear una nueva columna de valor anual (Valor_mensual * 12 meses) + impuesto
datos['Valor_anual'] = datos['Valor_mensual']*12 + datos['Impuesto']
datos.tail(5)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# ### **Crear columnas categóricas**

# %% [markdown]
# #### 1. Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
# Creo una nueva columna con la descripción, concatenando Tipo + barrio (Colonia) + Habitaciones y estacionamientos (Garages)
# .astype(str) para que no de error al concatenar valores numéricos.
# strings se concatenan solo con strings
datos['Descripcion'] = datos['Tipo'] + ' en la colonia ' +  datos['Colonia'] + \
                     ' con ' + datos['Habitaciones'].astype(str) + ' habitacion(es) y ' + \
                     datos['Garages'].astype(str) + ' plazas de estacionamiento.'
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# ...

# %%
# Veo la descripción según el índice proporcionado
datos.iloc[500].Descripcion
# Out:
# 'Departamento en la colonia Napoles con 1 habitacion(es) y 0 plazas de estacionamiento.'

# %% [markdown]
# #### 2. Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad. (Suite es un cuarto con baño)

# %%
# .apply() -> es el método que sirve para aplicarle una función, en este caso lambda
# Sí, si tiene suites; No, si no tiene suites
datos['Tiene_suite'] = datos['Suites'].apply(lambda x: 'Sí' if x > 0 else 'No' )
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# ...

# %%
# Guardamos el nuevo archivo con las solicitudes del equipo de desarrollo
datos.to_csv('/content/drive/MyDrive/Pandas/inmuebles_dev.csv',index=False,sep=';')

# %%
# Visualizamos el archivo
pd.read_csv('/content/drive/MyDrive/Pandas/inmuebles_dev.csv',sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
# ...

# %% [markdown]
# # **Para saber más:**

# %% [markdown]
# ## **Entendiendo el método groupby**

# %% [markdown]
# * El método groupby de Pandas permite agrupar y resumir datos de un DataFrame basado en uno o más criterios. Estos criterios pueden ser variables numéricas o categóricas, como columnas o índices del DataFrame.
#
# * La idea detrás de groupby es dividir los datos en grupos basados en los criterios seleccionados y luego aplicar una operación a estos grupos. Esta operación puede ser una función de agregación, como suma, promedio, recuento, desviación estándar, entre otras, o incluso una operación personalizada definida por el usuario.
#
# **Este método tiene varios parámetros, algunos de los cuales son:**
#
# **by:** Este es el parámetro más común y se utiliza para especificar la columna o columnas por las cuales queremos agrupar. Como argumento, podemos pasar el nombre de una columna o una lista de nombres de columnas;
#
#
# **axis:** Utilizamos este parámetro para especificar el eje a lo largo del cual queremos agrupar. El valor predeterminado es 0, lo que significa que se agruparán las filas. Si deseamos agrupar las columnas, debemos establecer este parámetro en 1;
#
#
# **sort:** Este parámetro es un booleano (True o False) que indica si los grupos deben ordenarse por el valor de la columna de agrupación. El valor predeterminado es True;
#
#
# **dropna:** Utilizamos este parámetro para controlar si los valores faltantes (NaN) se eliminarán o no durante el proceso de agrupación. El valor predeterminado es True.
#
#
# Veamos un ejemplo simple utilizando groupby. Supongamos que tenemos el siguiente DataFrame:

# %%
# Código del DataFrame:
import pandas as pd

df = pd.DataFrame({
   'Animal': ['Perro', 'Gato', 'Elefante', 'Perro', 'Gato', 'Elefante'],
   'Color': ['Negro', 'Blanco', 'Gris', 'Marrón', 'Negro', 'Marrón'],
   'Cantidad': [2, 3, 1, 4, 2, 2]
})
df
#Resultado, muestra el DataFrame
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %% [markdown]
# Aquí tenemos un DataFrame con datos sobre algunos animales. Usaremos groupby para agrupar los datos por tipo de animal y realizar la suma de la columna "Cantidad" para obtener el total de cada tipo de animal:

# %%
df.groupby('Animal').sum(numeric_only=True)
# Out:
#           Cantidad
# Animal
# Elefante         3
# Gato             5
# Perro            6

# %% [markdown]
# También podemos usar el método groupby para agrupar datos por múltiples columnas. Por ejemplo, agrupemos por tipo de animal y también por color, y realicemos la suma de la columna "Cantidad":

# %%
df.groupby(['Animal', 'Color'])[['Cantidad']].sum()
# Out:
#                  Cantidad
# Animal   Color
# Elefante Gris           1
#          Marrón         2
# Gato     Blanco         3
#          Negro          2
# Perro    Marrón         4
#          Negro          2

# %% [markdown]
# Así, podemos observar que groupby es un método muy útil para situaciones en las que necesitamos dividir los datos en grupos para analizar el comportamiento de estos grupos. Utilizando este método, podemos responder preguntas específicas sobre nuestros conjuntos de datos. Si desea aprender más sobre este método, le sugiero dos artículos:
#
# [Pandas GroupBy: Su guía para agrupar datos en Python](https://realpython.com/pandas-groupby/)
#
# [Explicación detallada del groupby de Pandas](https://towardsdatascience.com/be-careful-when-using-pandas-groupby-with-categorical-data-type-a1d31f66b162//)

# %% [markdown]
# # **DESAFÍO: VAMOS A PRACTICAR**

# %% [markdown]
# ## Ejercicio 1:

# %% [markdown]
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos análisis utilizando un archivo CSV diferente: [alumnos.csv](https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv).

# %% [markdown]
# ### 1. Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.

# %%
# 1. Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.
import pandas as pd
enlace = "https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv"
df_alumnos = pd.read_csv(enlace, sep=',')
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# ### 2. Visualiza las primeras 7 filas del DataFrame y las últimas 5.

# %%
# 2. Visualiza las primeras 7 filas del DataFrame y las últimas 5.
# primeras 7 filas
df_alumnos.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
# últimas 5 filas
df_alumnos.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %% [markdown]
# ### 3. Verifica la cantidad de filas y columnas en este DataFrame.

# %%
# 3. Verifica la cantidad de filas y columnas en este DataFrame, más el index (índice)
# 18 filas, 4 columnas
df_alumnos.shape
# Out:
# (18, 4)

# %% [markdown]
# ### 4. Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.

# %%
# 4. Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.
df_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
# Visualiza los nombres de cada columna
df_alumnos.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
# Tipos de datos de cada columna
df_alumnos.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
# Es una Serie que representa una sola columna.
df_alumnos['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
# Es un DataFrame que contiene solo las columnas "Edad" y "Nota".
df_alumnos[['Edad', 'Nota']]
# Out:
#     Edad  Nota
# 0     20   7.5
# 1     18   NaN
# 2     27   2.5
# 3     18   5.0
# 4     21  10.0
# 5     23   NaN
# 6     21   7.0
# 7     19   6.0
# 8     35   5.6
# 9     28   NaN
# 10    21   NaN
# 11    24   4.5
# 12    26  10.0
# 13    25   9.0
# 14    37   NaN
# 15    29   7.0
# 16    33   NaN
# 17    34   8.0

# %% [markdown]
# Nombre: String
#
# Edad: Entero
#
# Nota: Decimal
#
# Aprobado: String

# %%
# Aprobado es String, no boolean
df_alumnos['Aprobado'].unique()
# Out:
# array(['True', 'False', 'Verdadero'], dtype=object)

# %% [markdown]
# ### Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".

# %%
# EXTRA: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".
# Solo valores númericos
round(df_alumnos.describe(),2)
# Out:
#         Edad   Nota
# count  18.00  12.00
# mean   25.50   6.84
# std     6.07   2.26
# min    18.00   2.50
# 25%    21.00   5.45
# 50%    24.50   7.00
# 75%    28.75   8.25
# max    37.00  10.00

# %%
# Incluye todos los datos
round(df_alumnos.describe(include='all'),2)
# Out:
#          Nombre   Edad   Nota Aprobado
# count        18  18.00  12.00       18
# unique       18    NaN    NaN        3
# top     Alberto    NaN    NaN    False
# freq          1    NaN    NaN       11
# mean        NaN  25.50   6.84      NaN
# std         NaN   6.07   2.26      NaN
# min         NaN  18.00   2.50      NaN
# 25%         NaN  21.00   5.45      NaN
# 50%         NaN  24.50   7.00      NaN
# 75%         NaN  28.75   8.25      NaN
# max         NaN  37.00  10.00      NaN

# %% [markdown]
# ## Ejercicio 2:

# %% [markdown]
# ### 1. Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

# %%
# Muestra el conteo de nulos
df_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
# Reemplazo los nulos por nota: 1
df_alumnos = df_alumnos.fillna(1)
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   1.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   1.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   1.0      False
# 10    Danilo    21   1.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   1.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   1.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
# Compruebo que no hayan nulos
df_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %% [markdown]
# ### 2. Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
# Mi DataFrame de alumnos
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   1.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   1.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   1.0      False
# 10    Danilo    21   1.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   1.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   1.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
# Remover alumnos Carlos[7] y Alicia[8]
df_alumnos.drop([7,8],axis=0,inplace=True)

# %% [markdown]
# También puede ser así, en vez de [7,8] como índices:
#
# `alumnos_a_eliminar = df_alumnos.query('Nombre == "Alicia" | Nombre == "Carlos"').index`
#
# y luego:
#
# `df_alumnos.drop(alumnos_a_eliminar,axis=0,inplace=True)`

# %%
# Mostramos el DataFrame alumnos con los cambios realizados
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   1.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   1.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   1.0      False
# 10    Danilo    21   1.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   1.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   1.0      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# ### 3. Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
# Se reemplaza 'Verdadero' por 'True'
df_alumnos['Aprobado'] = df_alumnos['Aprobado'].replace('Verdadero','True')

# %%
# Filtro (o máscara) de alumnos aprobados
filtro_alumnos_aprobados = df_alumnos['Aprobado'] == 'True'

# %%
# Nuevo DataFrame solamente con los alumnos aprobados
df_alumnos_aprobados = df_alumnos[filtro_alumnos_aprobados].copy()
df_alumnos_aprobados
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   7.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   7.0     True
# 17     Nadia    34   8.0     True

# %%
# Verificamos que solo tenemos alumnos aprobados como datos únicos
df_alumnos_aprobados.Aprobado.unique()
# Out:
# array(['True'], dtype=object)

# %%
# En este caso, eliminaremos la columna 'Aprobado', ya que no la necesitaremos
df_alumnos_aprobados.drop('Aprobado',axis=1,inplace=True)
df_alumnos_aprobados
# Out:
#       Nombre  Edad  Nota
# 0    Alberto    20   7.5
# 4      Brian    21  10.0
# 6    Daniela    21   7.0
# 12  Stephany    26  10.0
# 13    Miriam    25   9.0
# 15    Milena    29   7.0
# 17     Nadia    34   8.0

# %% [markdown]
# ### 4. Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

# %%
# Guarda el DataFrame de alumnos en GoogleDrive
df_alumnos_aprobados.to_csv('/content/drive/MyDrive/Pandas/ejercicio_alumnos.csv',index=False)

# %%
# Lectura del archivo
pd.read_csv('/content/drive/MyDrive/Pandas/ejercicio_alumnos.csv')
# Out:
#      Nombre  Edad  Nota
# 0   Alberto    20   7.5
# 1     Brian    21  10.0
# 2   Daniela    21   7.0
# 3  Stephany    26  10.0
# 4    Miriam    25   9.0
# 5    Milena    29   7.0
# 6     Nadia    34   8.0

# %% [markdown]
# ### Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.

# %%
# Reemplaza las notas 7 por notas 8
df_alumnos_aprobados = df_alumnos_aprobados.replace(7,8)
df_alumnos_aprobados
# Out:
#       Nombre  Edad  Nota
# 0    Alberto    20   7.5
# 4      Brian    21  10.0
# 6    Daniela    21   8.0
# 12  Stephany    26  10.0
# 13    Miriam    25   9.0
# 15    Milena    29   8.0
# 17     Nadia    34   8.0

# %%
# Guardamos y leemos nuestro archivo
df_alumnos_aprobados.to_csv('/content/drive/MyDrive/Pandas/ejercicio_alumnos.csv',index=False)
pd.read_csv('/content/drive/MyDrive/Pandas/ejercicio_alumnos.csv')
# Out:
#      Nombre  Edad  Nota
# 0   Alberto    20   7.5
# 1     Brian    21  10.0
# 2   Daniela    21   8.0
# 3  Stephany    26  10.0
# 4    Miriam    25   9.0
# 5    Milena    29   8.0
# 6     Nadia    34   8.0
